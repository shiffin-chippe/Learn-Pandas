# %% [markdown]
# # Why Pandas?
# Pandas is the most popular python library that is used for data analysis.Eventhough the analysis of data can also be done with excel,it struggles with large data.It is used in Data sience

# %% [markdown]
# ### How to install it?
# Open terminal and type the below code:
#     pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### Create or download csv files
# Create a sample data set using excel and save the file as a '.csv' file in the same directory of your jupyter notebook or download any csv file from kaggle.

# %% [markdown]
# ## Working with pandas
# A dataframe is used to store your file.
# import your csv files by using:
# pd.read_csv('  ')

# %%
sample_data = pd.read_csv('data.csv')

# %% [markdown]
# Type the name of your dataframe to view your csv file

# %%
sample_data
# Out:
#             x           y
# 0   32.502345   31.707006
# 1   53.426804   68.777596
# 2   61.530358   62.562382
# 3   47.475640   71.546632
# 4   59.813208   87.230925
# 5   55.142188   78.211518
# 6   52.211797   79.641973
# 7   39.299567   59.171489
# 8   48.105042   75.331242
# 9   52.550014   71.300880
# 10  45.419730   55.165677
# 11  54.351635   82.478847
# 12  44.164049   62.008923
# 13  58.168471   75.392870
# 14  56.727208   81.436192
# 15  48.955889   60.723602
# 16  44.687196   82.892504
# 17  60.297327   97.379897
# 18  45.618644   48.847153
# 19  38.816818   56.877213
# 20  66.189817   83.878565
# 21  65.416052  118.591217
# 22  47.481209   57.251819
# 23  41.575643   51.391744
# 24  51.845187   75.380652
# 25  59.370822   74.765564
# 26  57.310003   95.455053
# 27  63.615561   95.229366
# 28  46.737619   79.052406
# 29  50.556760   83.432071
# ..        ...         ...
# 70  31.588117   50.392670
# 71  53.660932   63.642399
# 72  46.682229   72.247251
# ...

# %% [markdown]
# Use the function 'head' to view limited tumber of rows
#
# df"name".head("number of rows")

# %%
sample_data.head(3)
# Out:
#            x          y
# 0  32.502345  31.707006
# 1  53.426804  68.777596
# 2  61.530358  62.562382

# %% [markdown]
# similarly you can use the 'tail' function to view the last rows

# %%
sample_data.tail(3)
# Out:
#             x          y
# 97  50.039576  85.232007
# 98  48.149859  66.224958
# 99  25.128485  53.454394

# %% [markdown]
# Use the function 'iloc' to locate an element
#
# df"name".column"name".iloc["Element"]

# %%
sample_data.y.iloc[33]
# Out:
# 96.76956643

# %% [markdown]
# Use describe() function to get the statistical details of your data

# %%
sample_data.describe()
# Out:
#                 x           y
# count  100.000000  100.000000
# mean    48.958341   72.735051
# std      9.746379   16.658187
# min     25.128485   31.707006
# 25%     41.526164   60.788586
# 50%     49.634970   72.179542
# 75%     56.762631   83.215080
# max     70.346076  118.591217
